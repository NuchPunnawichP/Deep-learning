# %% [markdown]
# 3u  +   z   =   15
# u   +   2z  =   10

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_lines(data):
    for line_data in data:
        x = line_data['x']
        y = line_data['y']
        
        # Ensure x and y are numpy arrays
        x = np.array(x)
        y = np.array(y)
        
        plt.plot(x, y, label=line_data.get('label', 'Line'))
    plt.legend()
    plt.show()

# %%
A = np.array([ [3, 1], [1, 2] ])
b = np.array([15, 10])

# %%
X = np.hstack((A, b.reshape((2, 1))))
print(X)
# Out:
# [[ 3  1 15]
#  [ 1  2 10]]

# %%
try:
    x = np.linalg.solve(A, b)
    print('Non-singular Matrix')
    print("The intersection point is", x)
except np.linalg.LinAlgError as err:
    print(err)
# Out:
# Non-singular Matrix
# The intersection point is [4. 3.]

# %%
# preparing data
x_values = np.linspace(0, 15, 400)

y1_values = (15 - 3 * x_values) / 1
y2_values = (10 - 1 * x_values) / 2

# %%
# Plot the lines
plt.figure(figsize=(10, 6))
plt.plot(x_values, y1_values, label='3x + y = 15')
plt.plot(x_values, y2_values, label='x + 2y = 10')

# Plot the intersection point
plt.plot(int(x[0]), int(x[1]), 'ro', label='Intersection Point')

# labels
plt.title('Intersection of Linear Equations')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

print(f"The intersection point is at {tuple(x.astype(int))}")
# Out:
# The intersection point is at (4, 3)

# %% [markdown]
# อุ้ว ปวดหัวปวดใจ จุใจจริง ๆ
